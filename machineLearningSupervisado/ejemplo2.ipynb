# %%
import pandas as pd

# Crear DataFrame
df = pd.read_csv("cda-export.csv")
print(df.tail())
# Out:
#                                              entityid  \
# 75  f797a709-555a-407b-86f9-8e588941d8b3_80000000-...
# 76  f797a709-555a-407b-86f9-8e588941d8b3_80000000-...
# 77  f797a709-555a-407b-86f9-8e588941d8b3_80000000-...
# 78  f797a709-555a-407b-86f9-8e588941d8b3_80000000-...
# 79  f797a709-555a-407b-86f9-8e588941d8b3_80000000-...
#
#                               gridcellid              timeinstant  nitrogen  \
# 75  80000000-8890-0000-0001-800000062a9d  2024-07-25 09:34:45.757      1010
# 76  80000000-889a-0000-0001-800000062aab  2024-09-16 15:56:45.235       860
# 77  80000000-889b-0000-0001-800000062aab  2024-07-25 09:34:44.848       860
# 78  80000000-88a4-0000-0001-800000062a9f  2024-09-16 15:56:45.771       810
# 79  80000000-88a5-0000-0001-800000062a9f  2024-07-25 09:34:45.299       810
#
#     phosphorus  potassium  electricconductivity    ph  organiccontent  \
# 75       22.75        340                 24.19  8.75            1.66
# ...

# %%
#Numero de filas y columnas
print(df.shape)

#Nombres de las columnas
print(df.columns)

#Tipos de datos y valores nulos
print(df.info())
# Out:
# (80, 16)
# Index(['entityid', 'gridcellid', 'timeinstant', 'nitrogen', 'phosphorus',
#        'potassium', 'electricconductivity', 'ph', 'organiccontent',
#        'sandcontent', 'siltcontent', 'claycontent', 'density', 'batchid',
#        'refagriparcel', 'batchdate'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   entityid              80 non-null     object
#  1   gridcellid            80 non-null     object
#  2   timeinstant           80 non-null     object
#  3   nitrogen              80 non-null     int64
#  4   phosphorus            80 non-null     float64
#  5   potassium             80 non-null     int64
#  6   electricconductivity  80 non-null     float64
#  7   ph                    80 non-null     float64
#  8   organiccontent        80 non-null     float64
# ...

# %%
print(df.describe()) # Estadísticass numéricas básicas
# Out:
#           nitrogen  phosphorus   potassium  electricconductivity         ph  \
# count    80.000000   80.000000   80.000000             80.000000  80.000000
# mean   1002.362500   24.115875  337.775000             22.411250   8.595125
# std     174.125464    1.737549  115.795977              2.980243   0.273792
# min     560.000000   20.100000  100.000000             16.350000   8.020000
# 25%     890.000000   23.037500  250.000000             21.890000   8.310000
# 50%    1000.000000   24.150000  350.000000             22.250000   8.695000
# 75%    1102.500000   24.855000  400.000000             24.190000   8.792500
# max    1430.000000   29.500000  720.000000             26.890000   9.020000
#
#        organiccontent  sandcontent  siltcontent  claycontent    density
# count       80.000000     80.00000    80.000000    80.000000  80.000000
# mean         1.765250     31.01075    50.539750    18.449500   0.887545
# ...

# %%
print(df.iloc[3])
# Out:
# entityid                2856b33b-9968-46e0-96b8-9c5d278c8044_80000000-...
# gridcellid                           80000000-8855-0000-0001-800000062ad9
# timeinstant                                       2024-07-24 12:39:23.476
# nitrogen                                                             1000
# phosphorus                                                          24.21
# potassium                                                             380
# electricconductivity                                                23.22
# ph                                                                   8.88
# organiccontent                                                        1.9
# sandcontent                                                          29.0
# siltcontent                                                          56.0
# claycontent                                                          15.0
# density                                                            0.8024
# ...

# %%
print(df["nitrogen"])
# Out:
# 0     1210
# 1     1230
# 2     1130
# 3     1000
# 4     1430
#       ...
# 75    1010
# 76     860
# 77     860
# 78     810
# 79     810
# Name: nitrogen, Length: 80, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# entityid                0
# gridcellid              0
# timeinstant             0
# nitrogen                0
# phosphorus              0
# potassium               0
# electricconductivity    0
# ph                      0
# organiccontent          0
# sandcontent             0
# siltcontent             0
# claycontent             0
# density                 0
# batchid                 0
# refagriparcel           0
# batchdate               0
# dtype: int64

# %%
print(df.describe())
